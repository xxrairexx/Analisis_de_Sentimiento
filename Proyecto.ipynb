# %%
import pandas as pd

splits = {'train': 'plain_text/train-00000-of-00001.parquet', 'test': 'plain_text/test-00000-of-00001.parquet', 'unsupervised': 'plain_text/unsupervised-00000-of-00001.parquet'}
df = pd.read_parquet("hf://datasets/stanfordnlp/imdb/" + splits["train"])
# Out:
# La ejecución de celdas con 'Python 3.14.3' requiere el paquete ipykernel.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Crear un entorno de Python</a> con los paquetes necesarios.
#
# O instale "ipykernel" mediante el comando: "c:/Users/xxrairexx/AppData/Roaming/uv/python/cpython-3.14.3-windows-x86_64-none/python.exe -m pip install ipykernel -U --user --force-reinstall"
